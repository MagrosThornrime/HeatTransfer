# %%
from plotnine import ggplot, aes, geom_line
from pandas import DataFrame


path_to_file = "results.txt"
arguments, values = [], []
with open(path_to_file, "r") as f:
    text_lines = f.read().strip().splitlines()
for line in text_lines:
    argument, value = line.split()
    arguments.append(float(argument))
    values.append(float(value))

df = DataFrame({"x": arguments, "u": values})

ggplot(df) + aes(x="x", y="u") + geom_line()
# Out:
# c:\Users\Public\mes\venv\Lib\site-packages\plotnine\geoms\geom_path.py:98: PlotnineWarning: geom_path: Removed 2 rows containing missing values.
# <Figure Size: (640 x 480)>
